# %%
import pandas as pd
import os

# %%
# Đường dẫn thư mục chứa các file Excel
base_path = 'Data/Data raw'

# %%
# Đọc từng file Excel và gán vào các biến tương ứng
data1 = pd.read_excel(f'{base_path}/2020-Vietnam.xlsx')
data2 = pd.read_excel(f'{base_path}/2021-Vietnam.xlsx')
data3 = pd.read_excel(f'{base_path}/2022-Vietnam.xlsx')
data4 = pd.read_excel(f'{base_path}/2023-Vietnam.xlsx')
data5 = pd.read_excel(f'{base_path}/2024-Vietnam.xlsx')

# %%
# Kiểm tra danh sách các cột
print(data1.columns)
# Out:
# Index(['Mã', 'Tên công ty', 'Sàn', 'Ngành ICB - cấp 1', 'Ngành ICB - cấp 2',
#        'Ngành ICB - cấp 3', 'Ngành ICB - cấp 4',
#        'Quý\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        'Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        'Trạng thái kiểm toán\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        ...
#        'TM. Chi phí tài chính khác\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí sản xuất theo yếu tố\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí nguyên liệu, vật liệu\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí nhân công\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM.Chi phí khấu hao tài sản cố định\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí dịch vụ mua ngoài\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí khác bằng tiền\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
# ...

# %%
# Lọc các cột có chữ "BCTCKH." ở đầu
columns_to_select = ["Mã"] + [col for col in data1.columns if col.startswith("BCTCKH.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n" in data1.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n")  # Thêm "Năm" vào vị trí thứ hai

# Nếu biến year_column đã được định nghĩa và tồn tại trong data1, thêm vào danh sách
if 'year_column' in globals() and year_column in data1.columns:
    columns_to_select.insert(1, year_column)

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data1_BCTCKH = data1[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data1_BCTCKH.columns = data1_BCTCKH.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n", "", regex=False)
data1_BCTCKH.columns = data1_BCTCKH.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data1_BCTCKH.columns = data1_BCTCKH.columns.str.replace("BCTCKH.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data1_BCTCKH.columns:
    data1_BCTCKH = data1_BCTCKH.drop(columns=["Quý"])

# Đổi tên cột chứa thông tin năm thành "Năm"
if 'year_column' in globals() and year_column in data1.columns:
    data1_BCTCKH = data1_BCTCKH.rename(columns={year_column: "Năm"})

# Thay thế các giá trị NaN hoặc trống bằng 0
data1_BCTCKH = data1_BCTCKH.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên (nếu cột "Năm" tồn tại)
if "Năm" in data1_BCTCKH.columns:
    data1_BCTCKH["Năm"] = data1_BCTCKH["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data1_BCTCKH.head()
# Out:
#     Mã   Năm   Doanh thu kế hoạch   Tổng lợi nhuận kế toán trước thuế  \
# 0  ACB  2020         0.000000e+00                        1.060200e+13
# 1  BCM  2020         8.900000e+12                        2.700000e+12
# 2  BID  2020         0.000000e+00                        1.300000e+13
# 3  BVH  2020         1.510000e+12                        1.287500e+12
# 4  CTG  2020         0.000000e+00                        1.680000e+13
#
#     Lợi nhuận sau thuế thu nhập doanh nghiệp
# 0                               8.481600e+12
# 1                               2.300000e+12
# 2                               1.040000e+13
# 3                               1.030000e+12
# 4                               1.344000e+13

# %%
# Lọc các cột có chữ "BCTCKH." ở đầu
columns_to_select = ["Mã"] + [col for col in data2.columns if col.startswith("BCTCKH.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n" in data2.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data2_BCTCKH = data2[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data2_BCTCKH.columns = data2_BCTCKH.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n", "", regex=False)
data2_BCTCKH.columns = data2_BCTCKH.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data2_BCTCKH.columns = data2_BCTCKH.columns.str.replace("BCTCKH.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data2_BCTCKH.columns:
    data2_BCTCKH = data2_BCTCKH.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data2_BCTCKH = data2_BCTCKH.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên
if "Năm" in data2_BCTCKH.columns:
    data2_BCTCKH["Năm"] = data2_BCTCKH["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data2_BCTCKH.head()
# Out:
#     Mã   Năm   Doanh thu kế hoạch   Tổng lợi nhuận kế toán trước thuế  \
# 0  ACB  2021         0.000000e+00                        1.501800e+13
# 1  BCM  2021         9.680000e+12                        3.256000e+12
# 2  BID  2021         0.000000e+00                        2.060000e+13
# 3  BVH  2021         1.530000e+12                        1.312500e+12
# 4  CTG  2021         0.000000e+00                        1.945100e+13
#
#     Lợi nhuận sau thuế thu nhập doanh nghiệp
# 0                               1.201440e+13
# 1                               2.888000e+12
# 2                               1.648000e+13
# 3                               1.050000e+12
# 4                               1.556080e+13

# %%
# Lọc các cột có chữ "BCTCKH." ở đầu
columns_to_select = ["Mã"] + [col for col in data3.columns if col.startswith("BCTCKH.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n" in data3.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data3_BCTCKH = data3[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data3_BCTCKH.columns = data3_BCTCKH.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n", "", regex=False)
data3_BCTCKH.columns = data3_BCTCKH.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data3_BCTCKH.columns = data3_BCTCKH.columns.str.replace("BCTCKH.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data3_BCTCKH.columns:
    data3_BCTCKH = data3_BCTCKH.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data3_BCTCKH = data3_BCTCKH.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên (nếu cột "Năm" tồn tại)
if "Năm" in data3_BCTCKH.columns:
    data3_BCTCKH["Năm"] = data3_BCTCKH["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data3_BCTCKH.head()
# Out:
#     Mã   Năm   Doanh thu kế hoạch   Tổng lợi nhuận kế toán trước thuế  \
# 0  ACB  2022         0.000000e+00                        2.005800e+13
# 1  BCM  2022         9.460000e+12                        2.628000e+12
# 2  BID  2022         0.000000e+00                        2.646035e+13
# 3  BVH  2022         1.580000e+12                        1.375000e+12
# 4  CTG  2022         0.000000e+00                        0.000000e+00
#
#     Lợi nhuận sau thuế thu nhập doanh nghiệp
# 0                               1.604640e+13
# 1                               2.263000e+12
# 2                               2.116828e+13
# 3                               1.100000e+12
# 4                               0.000000e+00

# %%
# Lọc các cột có chữ "BCTCKH." ở đầu
columns_to_select = ["Mã"] + [col for col in data4.columns if col.startswith("BCTCKH.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n" in data4.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data4_BCTCKH = data4[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data4_BCTCKH.columns = data4_BCTCKH.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n", "", regex=False)
data4_BCTCKH.columns = data4_BCTCKH.columns.str.replace("Đơn vị: Tỷ VND", "", regex=False)
data4_BCTCKH.columns = data4_BCTCKH.columns.str.replace("BCTCKH.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data4_BCTCKH.columns:
    data4_BCTCKH = data4_BCTCKH.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data4_BCTCKH = data4_BCTCKH.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên (nếu cột "Năm" tồn tại)
if "Năm" in data4_BCTCKH.columns:
    data4_BCTCKH["Năm"] = data4_BCTCKH["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Lấy danh sách các cột cần chuyển đổi (ngoại trừ "Mã" và "Năm")
cols_to_convert = [col for col in data4_BCTCKH.columns if col not in ["Mã", "Năm"]]

# Nhân giá trị của các cột đó với 1000
data4_BCTCKH[cols_to_convert] = data4_BCTCKH[cols_to_convert].apply(lambda x: x * 1000)

# Hiển thị DataFrame sau khi xử lý
data4_BCTCKH.head()
# Out:
#     Mã   Năm   Doanh thu kế hoạch   Tổng lợi nhuận kế toán trước thuế  \
# 0  ACB  2023                  0.0                          20058000.0
# 1  BCM  2023            9460000.0                           2628000.0
# 2  BID  2023                  0.0                          26460350.0
# 3  BVH  2023            1580000.0                           1375000.0
# 4  CTG  2023                  0.0                          22500000.0
#
#     Lợi nhuận sau thuế thu nhập doanh nghiệp
# 0                                 16046400.0
# 1                                  2263000.0
# 2                                 21168280.0
# 3                                  1100000.0
# 4                                 18000000.0

# %%
# Lọc các cột có chữ "BCTCKH." ở đầu
columns_to_select = ["Mã"] + [col for col in data5.columns if col.startswith("BCTCKH.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n" in data5.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data5_BCTCKH = data5[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data5_BCTCKH.columns = data5_BCTCKH.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n", "", regex=False)
data5_BCTCKH.columns = data5_BCTCKH.columns.str.replace("Đơn vị: Tỷ VND", "", regex=False)
data5_BCTCKH.columns = data5_BCTCKH.columns.str.replace("BCTCKH.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data5_BCTCKH.columns:
    data5_BCTCKH = data5_BCTCKH.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data5_BCTCKH = data5_BCTCKH.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên (nếu cột "Năm" tồn tại)
if "Năm" in data5_BCTCKH.columns:
    data5_BCTCKH["Năm"] = data5_BCTCKH["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Lấy danh sách các cột cần chuyển đổi (ngoại trừ "Mã" và "Năm")
cols_to_convert = [col for col in data5_BCTCKH.columns if col not in ["Mã", "Năm"]]

# Nhân giá trị của các cột đó với 1000
data5_BCTCKH[cols_to_convert] = data5_BCTCKH[cols_to_convert].apply(lambda x: x * 1000)

# Hiển thị DataFrame sau khi xử lý
data5_BCTCKH.head()
# Out:
#     Mã   Năm   Doanh thu kế hoạch   Tổng lợi nhuận kế toán trước thuế  \
# 0  ACB  2024                  0.0                          20058000.0
# 1  BCM  2024            9460000.0                           2628000.0
# 2  BID  2024                  0.0                          26460350.0
# 3  BVH  2024            1580000.0                           1375000.0
# 4  CTG  2024                  0.0                          22500000.0
#
#     Lợi nhuận sau thuế thu nhập doanh nghiệp
# 0                                 16046400.0
# 1                                  2263000.0
# 2                                 21168280.0
# 3                                  1100000.0
# 4                                 18000000.0

# %%
# Đường dẫn thư mục xuất file
output_dir = r"Data\Data cleaned"
os.makedirs(output_dir, exist_ok=True)

# Tạo đường dẫn file Excel mới với tên "data_BCTCKH.xlsx"
output_file = os.path.join(output_dir, "data_BCTCKH.xlsx")

# Xuất các DataFrame data1_BCTCKH đến data5_BCTCKH vào file Excel với các sheet riêng biệt
with pd.ExcelWriter(output_file) as writer:
    data1_BCTCKH.to_excel(writer, sheet_name="data1_BCTCKH", index=False)
    data2_BCTCKH.to_excel(writer, sheet_name="data2_BCTCKH", index=False)
    data3_BCTCKH.to_excel(writer, sheet_name="data3_BCTCKH", index=False)
    data4_BCTCKH.to_excel(writer, sheet_name="data4_BCTCKH", index=False)
    data5_BCTCKH.to_excel(writer, sheet_name="data5_BCTCKH", index=False)

print(f"File Excel đã được lưu tại: {output_file}")
# Out:
# File Excel đã được lưu tại: Data\Data cleaned\data_BCTCKH.xlsx
