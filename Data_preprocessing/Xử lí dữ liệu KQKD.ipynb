# %%
import pandas as pd
import os

# %%
# Đường dẫn thư mục chứa các file Excel
base_path = 'Data/Data raw'

# %%
# Đọc từng file Excel và gán vào các biến tương ứng
data1 = pd.read_excel(f'{base_path}/2020-Vietnam.xlsx')
data2 = pd.read_excel(f'{base_path}/2021-Vietnam.xlsx')
data3 = pd.read_excel(f'{base_path}/2022-Vietnam.xlsx')
data4 = pd.read_excel(f'{base_path}/2023-Vietnam.xlsx')
data5 = pd.read_excel(f'{base_path}/2024-Vietnam.xlsx')

# %%
# Kiểm tra danh sách các cột
print(data1.columns)
# Out:
# Index(['Mã', 'Tên công ty', 'Sàn', 'Ngành ICB - cấp 1', 'Ngành ICB - cấp 2',
#        'Ngành ICB - cấp 3', 'Ngành ICB - cấp 4',
#        'Quý\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        'Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        'Trạng thái kiểm toán\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n',
#        ...
#        'TM. Chi phí tài chính khác\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí sản xuất theo yếu tố\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí nguyên liệu, vật liệu\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí nhân công\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM.Chi phí khấu hao tài sản cố định\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí dịch vụ mua ngoài\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
#        'TM. Chi phí khác bằng tiền\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\nĐơn vị: Triệu VND',
# ...

# %%
# Lọc các cột có chữ "KQKD." ở đầu
columns_to_select = ["Mã"] + [col for col in data1.columns if col.startswith("KQKD.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n" in data1.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n")  # Thêm "Năm" vào vị trí thứ hai

# Nếu biến year_column đã được định nghĩa và tồn tại trong data1, thêm vào danh sách
if 'year_column' in globals() and year_column in data1.columns:
    columns_to_select.insert(1, year_column)

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data1_KQKD = data1[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data1_KQKD.columns = data1_KQKD.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2020\n", "", regex=False)
data1_KQKD.columns = data1_KQKD.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data1_KQKD.columns = data1_KQKD.columns.str.replace("KQKD.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data1_KQKD.columns:
    data1_KQKD = data1_KQKD.drop(columns=["Quý"])

# Đổi tên cột chứa thông tin năm thành "Năm" (nếu year_column đã được định nghĩa và có trong data1)
if 'year_column' in globals() and year_column in data1.columns:
    data1_KQKD = data1_KQKD.rename(columns={year_column: "Năm"})

# Thay thế các giá trị NaN hoặc trống bằng 0
data1_KQKD = data1_KQKD.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên (nếu cột "Năm" tồn tại)
if "Năm" in data1_KQKD.columns:
    data1_KQKD["Năm"] = data1_KQKD["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data1_KQKD.head()
# Out:
#     Mã   Năm   Doanh thu bán hàng và cung cấp dịch vụ   Doanh thu thuần  \
# 0  ACB  2020                             0.000000e+00      0.000000e+00
# 1  BCM  2020                             6.703803e+12      6.504738e+12
# 2  BID  2020                             0.000000e+00      0.000000e+00
# 3  BVH  2020                             3.820489e+13      3.452404e+13
# 4  CTG  2020                             0.000000e+00      0.000000e+00
#
#     Lợi nhuận gộp về bán hàng và cung cấp dịch vụ  \
# 0                                    0.000000e+00
# 1                                    3.260634e+12
# 2                                    0.000000e+00
# 3                                   -2.040914e+12
# 4                                    0.000000e+00
#
#     Doanh thu hoạt động tài chính   Chi phí tài chính  \
# 0                    0.000000e+00        0.000000e+00
# 1                    2.503945e+10       -5.919616e+11
# 2                    0.000000e+00        0.000000e+00
# ...

# %%
# Lọc các cột có chữ "KQKD." ở đầu
columns_to_select = ["Mã"] + [col for col in data2.columns if col.startswith("KQKD.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n" in data2.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data2_KQKD = data2[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data2_KQKD.columns = data2_KQKD.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2021\n", "", regex=False)
data2_KQKD.columns = data2_KQKD.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data2_KQKD.columns = data2_KQKD.columns.str.replace("KQKD.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data2_KQKD.columns:
    data2_KQKD = data2_KQKD.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data2_KQKD = data2_KQKD.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên
if "Năm" in data2_KQKD.columns:
    data2_KQKD["Năm"] = data2_KQKD["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data2_KQKD.head()
# Out:
#     Mã   Năm   Doanh thu bán hàng và cung cấp dịch vụ   Doanh thu thuần  \
# 0  ACB  2021                             0.000000e+00      0.000000e+00
# 1  BCM  2021                             7.117480e+12      6.981768e+12
# 2  BID  2021                             0.000000e+00      0.000000e+00
# 3  BVH  2021                             3.999979e+13      3.683014e+13
# 4  CTG  2021                             0.000000e+00      0.000000e+00
#
#     Lợi nhuận gộp về bán hàng và cung cấp dịch vụ  \
# 0                                    0.000000e+00
# 1                                    3.222623e+12
# 2                                    0.000000e+00
# 3                                    6.135065e+11
# 4                                    0.000000e+00
#
#     Doanh thu hoạt động tài chính   Chi phí tài chính  \
# 0                    0.000000e+00        0.000000e+00
# 1                    1.136747e+11       -8.746710e+11
# 2                    0.000000e+00        0.000000e+00
# ...

# %%
# Lọc các cột có chữ "KQKD." ở đầu
columns_to_select = ["Mã"] + [col for col in data3.columns if col.startswith("KQKD.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n" in data3.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data3_KQKD = data3[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data3_KQKD.columns = data3_KQKD.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2022\n", "", regex=False)
data3_KQKD.columns = data3_KQKD.columns.str.replace("Đơn vị: Triệu VND", "", regex=False)
data3_KQKD.columns = data3_KQKD.columns.str.replace("KQKD.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data3_KQKD.columns:
    data3_KQKD = data3_KQKD.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data3_KQKD = data3_KQKD.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên
if "Năm" in data3_KQKD.columns:
    data3_KQKD["Năm"] = data3_KQKD["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Hiển thị DataFrame sau khi xử lý
data3_KQKD.head()
# Out:
#     Mã   Năm   Doanh thu bán hàng và cung cấp dịch vụ   Doanh thu thuần  \
# 0  ACB  2022                             0.000000e+00      0.000000e+00
# 1  BCM  2022                             6.527468e+12      6.506378e+12
# 2  BID  2022                             0.000000e+00      0.000000e+00
# 3  BVH  2022                             4.265051e+13      4.068825e+13
# 4  CTG  2022                             0.000000e+00      0.000000e+00
#
#     Lợi nhuận gộp về bán hàng và cung cấp dịch vụ  \
# 0                                    0.000000e+00
# 1                                    2.735950e+12
# 2                                    0.000000e+00
# 3                                    1.048512e+11
# 4                                    0.000000e+00
#
#     Doanh thu hoạt động tài chính   Chi phí tài chính  \
# 0                    0.000000e+00        0.000000e+00
# 1                    7.352661e+10       -8.795214e+11
# 2                    0.000000e+00        0.000000e+00
# ...

# %%
# Lọc các cột có chữ "KQKD." ở đầu
columns_to_select = ["Mã"] + [col for col in data4.columns if col.startswith("KQKD.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n" in data4.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data4_KQKD = data4[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data4_KQKD.columns = data4_KQKD.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2023\n", "", regex=False)
data4_KQKD.columns = data4_KQKD.columns.str.replace("Đơn vị: Tỷ VND", "", regex=False)
data4_KQKD.columns = data4_KQKD.columns.str.replace("KQKD.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data4_KQKD.columns:
    data4_KQKD = data4_KQKD.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data4_KQKD = data4_KQKD.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên
if "Năm" in data4_KQKD.columns:
    data4_KQKD["Năm"] = data4_KQKD["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Lấy danh sách các cột cần chuyển đổi (ngoại trừ "Mã" và "Năm")
cols_to_convert = [col for col in data4_KQKD.columns if col not in ["Mã", "Năm"]]

# Nhân giá trị của các cột đó với 1000
data4_KQKD[cols_to_convert] = data4_KQKD[cols_to_convert].apply(lambda x: x * 1000)

# Hiển thị DataFrame sau khi xử lý
data4_KQKD.head()
# Out:
#     Mã   Năm   Doanh thu bán hàng và cung cấp dịch vụ   Doanh thu thuần  \
# 0  ACB  2023                             0.000000e+00      0.000000e+00
# 1  BCM  2023                             8.174569e+06      7.882566e+06
# 2  BID  2023                             0.000000e+00      0.000000e+00
# 3  BVH  2023                             4.265988e+07      4.008048e+07
# 4  CTG  2023                             0.000000e+00      0.000000e+00
#
#     Lợi nhuận gộp về bán hàng và cung cấp dịch vụ  \
# 0                                    0.000000e+00
# 1                                    4.247833e+06
# 2                                    0.000000e+00
# 3                                   -2.539019e+06
# 4                                    0.000000e+00
#
#     Doanh thu hoạt động tài chính   Chi phí tài chính  \
# 0                    0.000000e+00        0.000000e+00
# 1                    1.310712e+05       -9.063686e+05
# 2                    0.000000e+00        0.000000e+00
# ...

# %%
# Lọc các cột có chữ "KQKD." ở đầu
columns_to_select = ["Mã"] + [col for col in data5.columns if col.startswith("KQKD.")]

# Nếu cột "Năm" tồn tại, thêm vào danh sách
if "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n" in data5.columns:
    columns_to_select.insert(1, "Năm\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n")  # Thêm "Năm" vào vị trí thứ hai

# Tạo DataFrame mới chỉ chứa các cột cần thiết
data5_KQKD = data5[columns_to_select]

# Loại bỏ các ký tự không mong muốn khỏi tên cột
data5_KQKD.columns = data5_KQKD.columns.str.replace("\nHợp nhất\nQuý: Hàng năm\nNăm: 2024\n", "", regex=False)
data5_KQKD.columns = data5_KQKD.columns.str.replace("Đơn vị: Tỷ VND", "", regex=False)
data5_KQKD.columns = data5_KQKD.columns.str.replace("KQKD.", "", regex=False)

# Loại bỏ cột "Quý" nếu tồn tại
if "Quý" in data5_KQKD.columns:
    data5_KQKD = data5_KQKD.drop(columns=["Quý"])

# Thay thế các giá trị NaN hoặc trống bằng 0
data5_KQKD = data5_KQKD.fillna(0)

# Chuyển giá trị trong cột "Năm" thành số nguyên
if "Năm" in data5_KQKD.columns:
    data5_KQKD["Năm"] = data5_KQKD["Năm"].astype(str).str.extract(r'(\d+)').astype(int)

# Lấy danh sách các cột cần chuyển đổi (ngoại trừ "Mã" và "Năm")
cols_to_convert = [col for col in data5_KQKD.columns if col not in ["Mã", "Năm"]]

# Nhân giá trị của các cột đó với 1000
data5_KQKD[cols_to_convert] = data5_KQKD[cols_to_convert].apply(lambda x: x * 1000)

# Hiển thị DataFrame sau khi xử lý
data5_KQKD.head()
# Out:
#     Mã   Năm   Doanh thu bán hàng và cung cấp dịch vụ   Doanh thu thuần  \
# 0  ACB  2024                             0.000000e+00      0.000000e+00
# 1  BCM  2024                             5.224571e+06      5.195123e+06
# 2  BID  2024                             0.000000e+00      0.000000e+00
# 3  BVH  2024                             4.269393e+07      3.986220e+07
# 4  CTG  2024                             0.000000e+00      0.000000e+00
#
#     Lợi nhuận gộp về bán hàng và cung cấp dịch vụ  \
# 0                                    0.000000e+00
# 1                                    3.392263e+06
# 2                                    0.000000e+00
# 3                                   -9.807260e+05
# 4                                    0.000000e+00
#
#     Doanh thu hoạt động tài chính   Chi phí tài chính  \
# 0                    0.000000e+00        0.000000e+00
# 1                    1.674123e+05       -1.309211e+06
# 2                    0.000000e+00        0.000000e+00
# ...

# %%
# Đường dẫn thư mục xuất file
output_dir = r"Data\Data cleaned"
os.makedirs(output_dir, exist_ok=True)

# Tạo đường dẫn file Excel mới với tên "data_KQKD.xlsx"
output_file = os.path.join(output_dir, "data_KQKD.xlsx")

# Xuất các DataFrame data1_KQKD đến data5_KQKD vào file Excel với các sheet riêng biệt
with pd.ExcelWriter(output_file) as writer:
    data1_KQKD.to_excel(writer, sheet_name="data1_KQKD", index=False)
    data2_KQKD.to_excel(writer, sheet_name="data2_KQKD", index=False)
    data3_KQKD.to_excel(writer, sheet_name="data3_KQKD", index=False)
    data4_KQKD.to_excel(writer, sheet_name="data4_KQKD", index=False)
    data5_KQKD.to_excel(writer, sheet_name="data5_KQKD", index=False)

print(f"File Excel đã được lưu tại: {output_file}")
# Out:
# File Excel đã được lưu tại: Data\Data cleaned\data_KQKD.xlsx
